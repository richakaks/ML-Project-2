# %% [markdown]
# ## Importing libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
import warnings
warnings.filterwarnings('ignore')

# %%
import matplotlib
np.__version__, pd.__version__, sns.__version__, matplotlib.__version__
# Out:
# ('1.24.4', '1.5.3', '0.12.2', '3.7.2')

# %% [markdown]
# ## 1. Load data

# %%
df = pd.read_csv('/Users/richakakati/Documents/ML/Machine-Learning-main (OLD)/Assignments/Assignment/Assignment 2/Cars.csv')

# %%
# print the first rows of data
df.head()
# Out:
#                            name  year  selling_price  km_driven    fuel  \
# 0        Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1  Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2      Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3     Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4        Maruti Swift VXI BSIII  2007         130000     120000  Petrol
#
#   seller_type transmission         owner     mileage   engine   max_power  \
# 0  Individual       Manual   First Owner   23.4 kmpl  1248 CC      74 bhp
# 1  Individual       Manual  Second Owner  21.14 kmpl  1498 CC  103.52 bhp
# 2  Individual       Manual   Third Owner   17.7 kmpl  1497 CC      78 bhp
# 3  Individual       Manual   First Owner   23.0 kmpl  1396 CC      90 bhp
# 4  Individual       Manual   First Owner   16.1 kmpl  1298 CC    88.2 bhp
#
#                      torque  seats
# 0            190Nm@ 2000rpm    5.0
# ...

# %%
# Check the shape of your data
df.shape
# Out:
# (8128, 13)

# %%
# Statistical info Hint: look up .describe()
df.describe()
# Out:
#               year  selling_price     km_driven        seats
# count  8128.000000   8.128000e+03  8.128000e+03  7907.000000
# mean   2013.804011   6.382718e+05  6.981951e+04     5.416719
# std       4.044249   8.062534e+05  5.655055e+04     0.959588
# min    1983.000000   2.999900e+04  1.000000e+00     2.000000
# 25%    2011.000000   2.549990e+05  3.500000e+04     5.000000
# 50%    2015.000000   4.500000e+05  6.000000e+04     5.000000
# 75%    2017.000000   6.750000e+05  9.800000e+04     5.000000
# max    2020.000000   1.000000e+07  2.360457e+06    14.000000

# %%
# Check Dtypes of your input data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8128 entries, 0 to 8127
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           8128 non-null   object
#  1   year           8128 non-null   int64
#  2   selling_price  8128 non-null   int64
#  3   km_driven      8128 non-null   int64
#  4   fuel           8128 non-null   object
#  5   seller_type    8128 non-null   object
#  6   transmission   8128 non-null   object
#  7   owner          8128 non-null   object
#  8   mileage        7907 non-null   object
#  9   engine         7907 non-null   object
#  10  max_power      7913 non-null   object
#  11  torque         7906 non-null   object
#  12  seats          7907 non-null   float64
# dtypes: float64(1), int64(3), object(9)
# memory usage: 825.6+ KB

# %%
# Check the column names
a = df.columns
print(a)
len(a)
# Out:
# Index(['name', 'year', 'selling_price', 'km_driven', 'fuel', 'seller_type',
#        'transmission', 'owner', 'mileage', 'engine', 'max_power', 'torque',
#        'seats'],
#       dtype='object')
# 13

# %% [markdown]
# ## 2. Exploratory Data Analysis

# %% [markdown]
# ### 2.1 Univariate analyis
#
# Single variable exploratory data anlaysis

# %% [markdown]
# #### Countplot

# %%
plt.figure(figsize=(10,8))
sns.countplot(data = df, x = 'seller_type')
# Out:
# <Axes: xlabel='seller_type', ylabel='count'>

# %%
plt.figure(figsize=(10,8))
sns.countplot(data = df, x = 'owner')
# Out:
# <Axes: xlabel='owner', ylabel='count'>

# %%
mapping = {
    'First Owner': 1,
    'Second Owner': 2,
    'Third Owner': 3,
    'Fourth & Above Owner': 4,
    'Test Drive Car': 5,
}
df['owner'] = df['owner'].map(mapping)
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
sns.countplot(data = df, x = 'seats')
# Out:
# <Axes: xlabel='seats', ylabel='count'>

# %%
sns.countplot(data = df, x = 'transmission')
# Out:
# <Axes: xlabel='transmission', ylabel='count'>

# %%
sns.countplot(data = df, x = 'fuel')
# Out:
# <Axes: xlabel='fuel', ylabel='count'>

# %%
df = df[~df['fuel'].str.contains('LPG') & ~df['fuel'].str.contains('CNG')]

df.shape
# Out:
# (8033, 13)

# %%
sns.countplot(data = df, x = 'fuel')
# Out:
# <Axes: xlabel='fuel', ylabel='count'>

# %%
df['mileage'] = df['mileage'].str.split().str[0].astype(float)
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
# ...

# %%
df['engine'] = df.engine.str.split().str[0].astype(float)

# %%
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission  owner  mileage  engine   max_power  \
# ...

# %%
df['max_power'] = df['max_power'].str.split().str[0].astype(float)
df
# Out:
#                               name  year  selling_price  km_driven    fuel  \
# 0           Maruti Swift Dzire VDI  2014         450000     145500  Diesel
# 1     Skoda Rapid 1.5 TDI Ambition  2014         370000     120000  Diesel
# 2         Honda City 2017-2020 EXi  2006         158000     140000  Petrol
# 3        Hyundai i20 Sportz Diesel  2010         225000     127000  Diesel
# 4           Maruti Swift VXI BSIII  2007         130000     120000  Petrol
# ...                            ...   ...            ...        ...     ...
# 8123             Hyundai i20 Magna  2013         320000     110000  Petrol
# 8124         Hyundai Verna CRDi SX  2007         135000     119000  Diesel
# 8125        Maruti Swift Dzire ZDi  2009         382000     120000  Diesel
# 8126               Tata Indigo CR4  2013         290000      25000  Diesel
# 8127               Tata Indigo CR4  2013         290000      25000  Diesel
#
#      seller_type transmission  owner  mileage  engine  max_power  \
# ...

# %%
df.rename(columns={'name':'brand'}, inplace = True)

# %%
df['brand'] = df.brand.str.split().str[0]
df
# Out:
#         brand  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
# 8126     Tata  2013         290000      25000  Diesel  Individual
# 8127     Tata  2013         290000      25000  Diesel  Individual
#
#      transmission  owner  mileage  engine  max_power  \
# 0          Manual      1    23.40  1248.0      74.00
# 1          Manual      2    21.14  1498.0     103.52
# ...

# %%
df = df.drop('torque', axis=1)

# %%
df
# Out:
#         brand  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
# 8126     Tata  2013         290000      25000  Diesel  Individual
# 8127     Tata  2013         290000      25000  Diesel  Individual
#
#      transmission  owner  mileage  engine  max_power  seats
# 0          Manual      1    23.40  1248.0      74.00    5.0
# ...

# %%
df.owner
# Out:
# 0       1
# 1       2
# 2       3
# 3       1
# 4       1
#        ..
# 8123    1
# 8124    4
# 8125    1
# 8126    1
# 8127    1
# Name: owner, Length: 8033, dtype: int64

# %%
sns.boxplot(x = df["owner"], y = np.log(df["selling_price"]));
plt.ylabel("selling_price")
plt.xlabel("owner")
# Out:
# Text(0.5, 0, 'owner')

# %% [markdown]
# We can see from the above graph that selling price of test drive cars are quite expensive. Therefore, we delete all samples related to it.

# %%
df = df[df['owner']!=5]
df.shape
# Out:
# (8028, 12)

# %%
df
# Out:
#         brand  year  selling_price  km_driven    fuel seller_type  \
# 0      Maruti  2014         450000     145500  Diesel  Individual
# 1       Skoda  2014         370000     120000  Diesel  Individual
# 2       Honda  2006         158000     140000  Petrol  Individual
# 3     Hyundai  2010         225000     127000  Diesel  Individual
# 4      Maruti  2007         130000     120000  Petrol  Individual
# ...       ...   ...            ...        ...     ...         ...
# 8123  Hyundai  2013         320000     110000  Petrol  Individual
# 8124  Hyundai  2007         135000     119000  Diesel  Individual
# 8125   Maruti  2009         382000     120000  Diesel  Individual
# 8126     Tata  2013         290000      25000  Diesel  Individual
# 8127     Tata  2013         290000      25000  Diesel  Individual
#
#      transmission  owner  mileage  engine  max_power  seats
# 0          Manual      1    23.40  1248.0      74.00    5.0
# ...

# %% [markdown]
# #### Distribution plot

# %%
sns.displot(data = df, x = 'year')

# %%
sns.displot(data = df, x = 'max_power')

# %%
sns.displot(data = df, x = 'engine')

# %%
sns.displot(data = df, x = 'selling_price')

# %%
sns.displot(data = df, x = 'mileage')

# %% [markdown]
# ### 2.2 Multivariate analysis
#
# Multiple variable exploratory data analysis

# %% [markdown]
# #### Boxplot

# %%
sns.boxplot(x = df["fuel"], y = np.log(df["selling_price"]));
plt.ylabel("selling_price")
plt.xlabel("fuel")
# Out:
# Text(0.5, 0, 'fuel')

# %%
sns.boxplot(x = df["fuel"], y = df["mileage"]);
plt.ylabel("mileage")
plt.xlabel("fuel")
# Out:
# Text(0.5, 0, 'fuel')

# %%
sns.boxplot(x = df["transmission"], y = np.log(df["selling_price"]));
plt.ylabel("selling_price")
plt.xlabel("transmission")
# Out:
# Text(0.5, 0, 'transmission')

# %%
sns.boxplot(x = df["transmission"], y = df["mileage"]);
plt.ylabel("mileage")
plt.xlabel("transmission")
# Out:
# Text(0.5, 0, 'transmission')

# %%
sns.boxplot(x = df["owner"], y = np.log(df["selling_price"]));
plt.ylabel("selling_price")
plt.xlabel("owner")
# Out:
# Text(0.5, 0, 'owner')

# %% [markdown]
# #### Scatterplot

# %%
sns.scatterplot(x = df['mileage'], y = np.log(df['selling_price']), hue=df['fuel'])
# Out:
# <Axes: xlabel='mileage', ylabel='selling_price'>

# %%
sns.scatterplot(x = df['max_power'], y = np.log(df['selling_price']), hue=df['fuel'])
# Out:
# <Axes: xlabel='max_power', ylabel='selling_price'>

# %%
sns.scatterplot(x = df['mileage'], y = np.log(df['selling_price']), hue=df['transmission'])
# Out:
# <Axes: xlabel='mileage', ylabel='selling_price'>

# %%
sns.scatterplot(x = df['max_power'], y = np.log(df['selling_price']), hue=df['transmission'])
# Out:
# <Axes: xlabel='max_power', ylabel='selling_price'>

# %% [markdown]
# #### Correlation Matrix
#
# We use correlation matrix to find the strong factors to predict the car prices.  We will also check whether certain features are too correlated.

# %%
from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()
df["fuel"] = le.fit_transform(df["fuel"])
le.classes_
# Out:
# array(['Diesel', 'Petrol'], dtype=object)

# %%
df.fuel.unique()
# Out:
# array([0, 1])

# %%
df["seller_type"] = le.fit_transform(df["seller_type"])
le.classes_
# Out:
# array(['Dealer', 'Individual', 'Trustmark Dealer'], dtype=object)

# %%
df.seller_type.unique()
# Out:
# array([1, 0, 2])

# %%
le.transform(["Dealer", "Individual", "Trustmark Dealer"])
# Out:
# array([0, 1, 2])

# %%
df["transmission"] = le.fit_transform(df["transmission"])
le.classes_
# Out:
# array(['Automatic', 'Manual'], dtype=object)

# %%
df.transmission.unique()
# Out:
# array([1, 0])

# %%
le.transform(["Automatic", "Manual"])
# Out:
# array([0, 1])

# %%
df
# Out:
#         brand  year  selling_price  km_driven  fuel  seller_type  \
# 0      Maruti  2014         450000     145500     0            1
# 1       Skoda  2014         370000     120000     0            1
# 2       Honda  2006         158000     140000     1            1
# 3     Hyundai  2010         225000     127000     0            1
# 4      Maruti  2007         130000     120000     1            1
# ...       ...   ...            ...        ...   ...          ...
# 8123  Hyundai  2013         320000     110000     1            1
# 8124  Hyundai  2007         135000     119000     0            1
# 8125   Maruti  2009         382000     120000     0            1
# 8126     Tata  2013         290000      25000     0            1
# 8127     Tata  2013         290000      25000     0            1
#
#       transmission  owner  mileage  engine  max_power  seats
# 0                1      1    23.40  1248.0      74.00    5.0
# 1                1      2    21.14  1498.0     103.52    5.0
# ...

# %%
df1 = df.drop("brand",axis = 1)
plt.figure(figsize = (15,8))
sns.heatmap(df1.corr(), annot=True, cmap="coolwarm")
# Out:
# <Axes: >

# %% [markdown]
# From the correlation matrix, notice that year, engine, and max_power are some of the best features we can choose to predict car price.

# %%
import ppscore as pps

# before using pps, let's drop country and year
dfcopy = df.copy()
dfcopy.drop(['brand'], axis=1, inplace=True)

#this needs some minor preprocessing because seaborn.heatmap unfortunately does not accept tidy data
matrix_df = pps.matrix(dfcopy)[['x', 'y', 'ppscore']].pivot(columns='x', index='y', values='ppscore')

#plot
plt.figure(figsize = (15,8))
sns.heatmap(matrix_df, vmin=0, vmax=1, cmap="Blues", linewidths=0.5, annot=True)
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %% [markdown]
# ### Getting X and y in the right shape

# %%
X = df
X.shape #number of samples, number of features

m = X.shape[0]  #number of samples
n = X.shape[1]  #number of features

print(m, n)
# Out:
# 8028 12

# %%
y = np.log(df['selling_price']) #target variable

# %%
y.shape #number of samples
# Out:
# (8028,)

# %%
y
# Out:
# 0       13.017003
# 1       12.821258
# 2       11.970350
# 3       12.323856
# 4       11.775290
#           ...
# 8123    12.676076
# 8124    11.813030
# 8125    12.853176
# 8126    12.577636
# 8127    12.577636
# Name: selling_price, Length: 8028, dtype: float64

# %%
# number of rows in X is the same as number of rows in y
# because so we have yhat for all y
assert m == y.shape[0]

# %% [markdown]
# ## 3. Feature selection

# %%
#X is our strong features
X = df[['mileage','engine','max_power']]

#y is predictant
y = np.log(df["selling_price"])

# %% [markdown]
# ### Train test split

# %%
from sklearn.model_selection import train_test_split #to split the dataset for training and testing

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42) #random state is a seed value

# %%
assert len(X_train)  == len(y_train)
assert len(X_test)   == len(y_test)

# %% [markdown]
# ## 4. Preprocessing

# %% [markdown]
# ### Null values

# %%
X_train[['mileage','engine','max_power']].isna().sum() #check for missing values
# Out:
# mileage      154
# engine       154
# max_power    149
# dtype: int64

# %%
X_test[['mileage','engine','max_power']].isna().sum() #check for missing values
# Out:
# mileage      60
# engine       60
# max_power    59
# dtype: int64

# %%
y_train.isna().sum() #check for missing values
# Out:
# 0

# %%
y_test.isna().sum() #check for missing values
# Out:
# 0

# %%
sns.displot(data=df, x='mileage') #check for outliers

# %%
sns.displot(data=df, x='engine') #check for outliers

# %%
sns.displot(data=df, x='max_power') # max_power is skewed #check for outliers

# %% [markdown]
# From the above three graphs, we notice that the columns engine, mileage, and max_power have null values.

# %%
sns.displot(y_train) # y_train is log of selling price

# %%
sns.displot(y_test) # y_test is log of selling price

# %% [markdown]
# However, the above two graphs for y_train and y_test do not seem to have any null values.
# Therefore, we do not need to impute any data.

# %%
#fill the training set first!
X_train['mileage'].fillna(X_train['mileage'].median(), inplace=True)
X_train['engine'].fillna(X_train['engine'].median(), inplace=True)
X_train['max_power'].fillna(X_train['max_power'].median(), inplace=True)

# %%
#fill the testing set with the training distribution first!
X_test['mileage'].fillna(X_train['mileage'].median(), inplace=True)
X_test['engine'].fillna(X_train['engine'].median(), inplace=True)
X_test['max_power'].fillna(X_train['max_power'].median(), inplace=True)

# %%
#checking for null values again
X_train[['mileage','engine','max_power']].isna().sum()
# Out:
# mileage      0
# engine       0
# max_power    0
# dtype: int64

# %%
X_test[['mileage','engine','max_power']].isna().sum() #checking for null values again
# Out:
# mileage      0
# engine       0
# max_power    0
# dtype: int64

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape #checking the shapes
# Out:
# ((5619, 3), (2409, 3), (5619,), (2409,))

# %%
X_train.to_csv('app/X_train.csv', index=False)   ## to use standard scalar later in the web application for fitting the new data provided

# %% [markdown]
# ### Checking Outliers

# %%
# Create a dictionary of columns.
col_dict = {'mileage':2,'engine':3,'max_power':4}

# Detect outliers in each variable using box plots.
plt.figure(figsize=(20,30))

for variable,i in col_dict.items():
                     plt.subplot(5,4,i)
                     plt.boxplot(X_train[variable])
                     plt.title(variable)

plt.show()

# %%
def outlier_count(col, data = X_train):
    
    # calculate your 25% quatile and 75% quatile
    q75, q25 = np.percentile(data[col], [75, 25])
    
    # calculate your inter quatile
    iqr = q75 - q25
    
    # min_val and max_val
    min_val = q25 - (iqr*1.5)
    max_val = q75 + (iqr*1.5)
    
    # count number of outliers, which are the data that are less than min_val or more than max_val calculated above
    outlier_count = len(np.where((data[col] > max_val) | (data[col] < min_val))[0])
    
    # calculate the percentage of the outliers
    outlier_percent = round(outlier_count/len(data[col])*100, 2)
    
    if(outlier_count > 0):
        print("\n"+15*'-' + col + 15*'-'+"\n")
        print('Number of outliers: {}'.format(outlier_count))
        print('Percent of data that is outlier: {}%'.format(outlier_percent))

# %%
for col in X_train.columns:
    outlier_count(col)
# Out:
# ---------------mileage---------------
#
# Number of outliers: 14
# Percent of data that is outlier: 0.25%
#
# ---------------engine---------------
#
# Number of outliers: 836
# Percent of data that is outlier: 14.88%
#
# ---------------max_power---------------
#
# Number of outliers: 409
# Percent of data that is outlier: 7.28%

# %% [markdown]
# ### Scaling

# %%
from sklearn.preprocessing import StandardScaler

# feature scaling helps improve reach convergence faster
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test  = scaler.transform(X_test)

# %% [markdown]
# ###  Adding intercepts

# %%
# np.ones((shape))
intercept = np.ones((X_train.shape[0], 1))

# concatenate the intercept based on axis=1
X_train = np.concatenate((intercept, X_train), axis=1)

# np.ones((shape))
intercept = np.ones((X_test.shape[0], 1))

# concatenate the intercept based on axis=1
X_test = np.concatenate((intercept, X_test), axis=1)

# %%
# Let's check shapes of all X_train, X_test, y_train, y_test
print("Shape of X_train: ", X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ", y_train.shape)
print("Shape of y_test: ", y_test.shape)
# Out:
# Shape of X_train:  (5619, 4)
# Shape of X_test:  (2409, 4)
# Shape of y_train:  (5619,)
# Shape of y_test:  (2409,)

# %% [markdown]
# # TASK 1 : Implementation
# ## 5. Modeling

# %% [markdown]
# For the below code to run correctly, you should run mlflow, either in your computer or in docker..
#
# Better to use docker because we will need it anyway in the final deployment task..
#
# Once you run a docker successfully for mlflow, your url will be localhost:$port_no$ that you assign while building the docker
#
# Then you should uncomment the line mlflow.set_tracking_uri("....")
#
# You should also create the experiment in the mlflow if it is not created...
#
# In your case i think you have already succeded running mlflow in docker, also you should have made the experiment name.. To check see you running docker container.. If not found, run the mlflow docker container, then create the experiment name then set_experiment

# %%
#experiment tracking
import mlflow
import os
# # This the dockerized method.
# # We build two docker containers, one for python/jupyter and another for mlflow.
# # The url `mlflow` is resolved into another container within the same composer.
mlflow.set_tracking_uri("http://0.0.0.0:5001")
# # In the dockerized way, the user who runs this code will be `root`.
# # The MLflow will also log the run user_id as `root`.
# # To change that, we need to set this environ["LOGNAME"] to your name.
# os.environ["LOGNAME"] = "richakakati"
# mlflow.create_experiment(name="car_price_prediction_a2_final")  #create if you haven't create
mlflow.set_experiment(experiment_name="car_price_prediction_a2_final")
# Out:
# <Experiment: artifact_location='mlflow-artifacts:/558464694233884448', creation_time=1695149473350, experiment_id='558464694233884448', last_update_time=1695149473350, lifecycle_stage='active', name='car_price_prediction_a2_final', tags={}>

# %%
from sklearn.model_selection import KFold

class LinearRegression(object):
    
    #Adding Crossvalidation for each experiment
    kfold = KFold(n_splits=3)
            
    def __init__(self, regularization, lr=0.001, method='batch', grad_init='xavier', polynomial=True, degree=3,
                 use_momentum=True, momentum=0.9, num_epochs=500, batch_size=50, cv=kfold):
        self.lr         = lr
        self.num_epochs = num_epochs
        self.batch_size = batch_size
        self.method     = method
        self.cv         = cv
        self.regularization = regularization
        self.use_momentum = use_momentum        # will store:'true' or 'false' depending on the exp
        self.momentum = momentum                # if defined will use the value 0.9
        self.grad_init = grad_init             
        self.polynomial = polynomial            # will store true or false depending on the exp
        self.degree = degree                    # if defined will use the ploynomial of degree 2
        self.prev_grad = 0

    # function to calculate mse for one fold in cv
    def mse(self, ytrue, ypred):
        return ((ypred - ytrue) ** 2).sum() / ytrue.shape[0]
    
    # function to calculate r2 for one fold in cv
    def r2(self, ytrue, ypred):
        return 1 - ((ytrue - ypred) ** 2).sum() / ((ytrue - ytrue.mean()) ** 2).sum()

    # function to calculate average mse for all kfold_scores
    def avgMse(self):
        return np.sum(np.array(self.kfold_scores))/len(self.kfold_scores)
    
    # function to calculate average r2 for all kfold_scores
    def avgr2(self):
        return np.sum(np.array(self.kfold_r2))/len(self.kfold_r2)
    
    # function where we will do training!!
    def fit(self, X_train, y_train):
        
        # Store column names for later use
        #self.columns = X_train.columns

        #Check if our experiment is polynomial or normal linear regression
        # if self.polynomial is True will use polynomial, By default self.polynomial is True
        if self.polynomial == True:
            X_train = self._transform_features(X_train)
            print("Using Polynomial")
        else:
            print("Using Linear")
            #X_train = X_train.to_numpy()

        #Convert the array to numpy array    
        y_train = y_train.to_numpy()

        #create a list of kfold scores
        self.kfold_scores = list()
        self.kfold_r2 = list()
        
        #reset val loss ----> This will be used in our first epoch after first epoch we will replace this value 
        # with the loss value in validation set in first epoch for 2nd epoch and so on..
        self.val_loss_old = np.infty

        #kfold.split in the sklearn.....
        for fold, (train_idx, val_idx) in enumerate(self.cv.split(X_train)):
            
            X_cross_train = X_train[train_idx]
            y_cross_train = y_train[train_idx]
            X_cross_val   = X_train[val_idx]
            y_cross_val   = y_train[val_idx]
            
            #initialize weights using Xavier method
            if self.grad_init == 'xavier':
                #calculate the range for the weights with number of samples
                lower, upper = -(1 / np.sqrt(X_cross_train.shape[0])), 1 / np.sqrt(X_cross_train.shape[0])
                #randomize weights then scale them using lower and upper bounds
                self.theta = np.random.rand(X_cross_train.shape[1])
                self.theta = lower + self.theta * (upper - lower)

            #initialize weights with zero
            elif self.grad_init == 'zero':
                self.theta = np.zeros(X_cross_train.shape[1])
            
            #define X_cross_train as only a subset of the data
            #how big is this subset?  => mini-batch size ==> 50
            
            #one epoch will exhaust the WHOLE training set
            with mlflow.start_run(run_name=f"Fold-{fold}", nested=True):
                
                params = {"method": self.method, "lr": self.lr, "reg": type(self).__name__}
                mlflow.log_params(params=params)
                
                for epoch in range(self.num_epochs):                    
                
                    #with replacement or no replacement
                    #with replacement means just randomize
                    #with no replacement means 0:50, 51:100, 101:150, ......300:323

                    #shuffle your index
                    perm = np.random.permutation(X_cross_train.shape[0])
                            
                    X_cross_train = X_cross_train[perm]
                    y_cross_train = y_cross_train[perm]
                    
                    if self.method == 'sto':
                        for batch_idx in range(X_cross_train.shape[0]):
                            X_method_train = X_cross_train[batch_idx].reshape(1, -1) #(11,) ==> (1, 11) ==> (m, n)
                            y_method_train = y_cross_train[batch_idx].reshape(1, )  #(1, )
                            train_loss = self._train(X_method_train, y_method_train)                   
                    elif self.method == 'mini':
                        for batch_idx in range(0, X_cross_train.shape[0], self.batch_size):
                            #batch_idx = 0, 50, 100, 150
                            X_method_train = X_cross_train[batch_idx:batch_idx+self.batch_size, :]    
                            y_method_train = y_cross_train[batch_idx:batch_idx+self.batch_size]
                            train_loss = self._train(X_method_train, y_method_train)                   ###
                    else:
                        X_method_train = X_cross_train
                        y_method_train = y_cross_train
                        train_loss = self._train(X_method_train, y_method_train)                        ###

                    mlflow.log_metric(key="train_loss", value=train_loss, step=epoch)

                    yhat_val = self.predict(X_cross_val)
                    val_loss_new = self.mse(y_cross_val, yhat_val)
                    val_r2_new = self.r2(y_cross_val, yhat_val)
                    mlflow.log_metric(key="val_loss", value=val_loss_new, step=epoch)
                    mlflow.log_metric(key="val_r2", value=val_r2_new, step=epoch)
                    
                    #early stopping
                    if np.allclose(val_loss_new, self.val_loss_old):              
                        break
                    self.val_loss_old = val_loss_new
            
                self.kfold_scores.append(val_loss_new)
                self.kfold_r2.append(val_r2_new)
                print(f"Fold {fold} mse: {val_loss_new}")
                print(f"Fold {fold} r2: {val_r2_new}")

    # def _transform_features(self, X):
    #     X = X.to_numpy()
    #     for i in range(2, self.degree+1):
    #         X = np.concatenate((X, X[:, 1:] ** i), axis=1)
    #     return X
    
    def _transform_features(self, X):
        # Transform input features to include polynomial degree --> highest degree is taken
        X_poly = np.column_stack([X ** (self.degree)])        
        return X_poly

    def _train(self, X, y): #X is (m, n) and y is (m, )
        yhat = self.predict(X) #===>(m, )
        m    = X.shape[0] #number of samples
        if self.regularization:
            grad = (1/m) * X.T @ (yhat - y) + self.regularization.derivation(self.theta) #===>(n, m) @ (m, ) = (n, )
        else:
            grad = (1/m) * X.T @ (yhat - y)
        if self.use_momentum == True:
            self.step = self.lr * grad
            self.theta = self.theta - self.step  +  self.momentum * self.prev_grad
            self.prev_grad = self.step
        else:
            self.theta = self.theta - self.lr * grad
        return self.mse(y, yhat)
 
    def predict(self, X):
        if self.polynomial == True:
            X = self._transform_features(X)
        return X @ self.theta   #===>(m, n) @ (n, )

    def _coef(self):
        return self.theta[1:]  #remind that theta is (w0, w1, w2, w3, w4.....wn)
                               #w0 is the bias or the intercept
                               #w1....wn are the weights / coefficients / theta
    def _bias(self):
        return self.theta[0]

    # def feature_importance(self, width=5, height=10):
    #     if self.theta is not None and self.columns is not None:
    #         coefs = pd.DataFrame(data=self.theta, index=self.columns, columns=["Coefficients"])  
    #         coefs.plot(kind='barh', figsize=(width, height))
    #         plt.title("Feature Importance")
    #         plt.show()
    #     else:
    #         print("No features found to calculate the feature importance")

    # def feature_importance(self):
    #     feature_importances = model._coef()
    #     sorted_idx = feature_importances.argsort()
    #     plt.barh(X.columns[sorted_idx], feature_importances[sorted_idx])
    #     plt.xlabel("Feature Importance")
    #     plt.show()

# %%
class LassoPenalty:
    
    def __init__(self, l):
        self.l = l # lambda value
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.abs(theta))
        
    def derivation(self, theta):
        return self.l * np.sign(theta)
    
class RidgePenalty:
    
    def __init__(self, l):
        self.l = l
        
    def __call__(self, theta): #__call__ allows us to call class as method
        return self.l * np.sum(np.square(theta))
        
    def derivation(self, theta):
        return self.l * 2 * theta
    
class ElasticPenalty:
    
    def __init__(self, l = 0.1, l_ratio = 0.5):
        self.l = l 
        self.l_ratio = l_ratio

    def __call__(self, theta):  #__call__ allows us to call class as method
        l1_contribution = self.l_ratio * self.l * np.sum(np.abs(theta))
        l2_contribution = (1 - self.l_ratio) * self.l * 0.5 * np.sum(np.square(theta))
        return (l1_contribution + l2_contribution)

    def derivation(self, theta):
        l1_derivation = self.l * self.l_ratio * np.sign(theta)
        l2_derivation = self.l * (1 - self.l_ratio) * theta
        return (l1_derivation + l2_derivation)

# %%
# Define classes for Lasso, Ridge, ElasticNet, and Normal (No Regularization) linear regression
class Lasso(LinearRegression):
    def __init__(self, l, lr, method, grad_init, polynomial, degree, use_momentum, momentum):
        self.regularization = LassoPenalty(l)
        super().__init__(self.regularization, lr, method, grad_init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

class Ridge(LinearRegression):
    def __init__(self, l, lr, method, grad_init, polynomial, degree, use_momentum, momentum):
        self.regularization = RidgePenalty(l)
        super().__init__(self.regularization, lr, method, grad_init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

class ElasticNet(LinearRegression):
    def __init__(self, l, lr, method, grad_init, polynomial, degree, use_momentum, momentum, l_ratio=0.5):
        self.regularization = ElasticPenalty(l, l_ratio)
        super().__init__(self.regularization, lr, method, grad_init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

class Normal(LinearRegression):  
    def __init__(self, l, lr, method, grad_init, polynomial, degree, use_momentum, momentum):
        self.regularization = None  # No regularization
        super().__init__(self.regularization, lr, method, grad_init, polynomial, degree, use_momentum, momentum)
    def avgMSE(self):
        return np.sum(np.array(self.kfold_scores)) / len(self.kfold_scores)

# %%
#helper function for looping classnames
import sys

def str_to_class(classname):
    return getattr(sys.modules[__name__], classname)

# %% [markdown]
# Experiment only implementing the regularization with full batch gradient descent and momentum.
# Model is Polynomial with degree 2 for the below experiment

# %%
regs = ["Ridge", "Lasso", "ElasticNet", "Normal"]

# Looping through all regression methods
for reg in regs:
    #Hard quoting other params
    params = {"method": "batch", "l": 0.1, "lr": 0.1,  "polynomial": True, "grad_init" :"xavier", 
    "use_momentum" :True,  "momentum":0.9, "degree":2}
    mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}", nested=True)
    
    print("="*5, reg, "="*5, "Using polynomial of degree 2")

    #Specifying the type of regression and setting up the model based on it
    type_of_regression = str_to_class(reg)    #Ridge, Lasso, ElasticNet
    #Passing the params 
    model = type_of_regression(**params)
    #Fitting the model
    model.fit(X_train, y_train)
    #Calculating avgMse and r2 for the speicified params
    mse = model.avgMSE()
    r2 = model.avgr2()

    #Predicting using the model
    yhat = model.predict(X_train)    
    
    print("Test MSE: ", mse)
    print("Test R2: ", r2)
    # Logging the metrics in ml flow
    mlflow.log_metric(key="test_mse", value=mse)
    mlflow.log_metric(key="test_r2", value=r2)

    signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
    mlflow.sklearn.log_model(model, artifact_path='model', signature=signature)


    mlflow.end_run()
# Out:
# ===== Ridge ===== Using polynomial of degree 2
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Lasso ===== Using polynomial of degree 2
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== ElasticNet ===== Using polynomial of degree 2
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Normal ===== Using polynomial of degree 2
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf

# %% [markdown]
# Repeating above experiment for Linear but Polynomial model of degree 3

# %%
regs = ["Ridge", "Lasso", "ElasticNet","Normal"]
ispoly= [True, False]

for reg in regs:
    for t in ispoly:

        params = {"method": "batch","polynomial": t,  "lr": 0.1, "l": 0.1, "grad_init" :"xavier", 
        "degree":3, "use_momentum" :True,  "momentum":0.9}
        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{t}", nested=True)
        
        print("="*5, reg, "="*5)
        if t == True:
            print("Using Polynomial")
        else:
            print("Using Linear")
        type_of_regression = str_to_class(reg)   
        model = type_of_regression(**params)  
        model.fit(X_train, y_train)
        yhat = model.predict(X_train)
        mse = model.avgMSE()
        r2 = model.avgr2()
        

        print("Test MSE: ", mse)
        print("Test R2: ", r2)

        mlflow.log_metric(key="test_mse", value=mse)
        mlflow.log_metric(key="test_r2", value=r2)

        signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
        mlflow.sklearn.log_model(model, artifact_path='model', signature=signature)

        mlflow.end_run()
# Out:
# ===== Ridge =====
# Using Polynomial
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Ridge =====
# Using Linear
# Using Linear
# Fold 0: 5.24355813825554
# Fold 0: -6.637202069092008
# Fold 1: 5.090784945999756
# Fold 1: -6.038529938311812
# Fold 2: 5.165486913235505
# Fold 2: -6.4385417029384735
# Test MSE:  5.1666099991636
# Test R2:  -6.3714245701140975
# ===== Lasso =====
# Using Polynomial
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Lasso =====
# Using Linear
# Using Linear
# Fold 0: 0.37774100068171573
# Fold 0: 0.44982313995148215
# Fold 1: 0.3810768315943413
# Fold 1: 0.47312237377431965
# Fold 2: 0.3698814299956798
# Fold 2: 0.46735351606147
# Test MSE:  0.3762330874239123
# Test R2:  0.46343300992909064
# ===== ElasticNet =====
# Using Polynomial
# Using Polynomial
# ...

# %% [markdown]
# ### From the above experiment Normal Linear model performed the best!!

# %% [markdown]
# # Task 2
# ## Experiment

# %% [markdown]
# Testing the above model with different learning rates:

# %%
regs = ["Ridge", "Lasso", "ElasticNet","Normal"]
ispoly= [True, False]
lrs = [0.01,0.001,0.0001]
momentums =[True, False]
for reg in regs:
    for t in ispoly:
        for lr in lrs:
            for momentum in momentums:
                params = {"method": "batch","polynomial": t,  "lr": lr, "l": 0.1, "grad_init" :"xavier", 
                "degree":3, "use_momentum" :momentum,  "momentum":0.9}
                mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{t}-momentum{momentum}", nested=True)
                
                print("="*5, reg, "="*5)
                if t == True:
                    if momentum == True:
                        print(f"Using Polynomial with lr={lr} with momentum 0.9")
                    else:
                        print(f"Using Polynomial with lr={lr} without momentum")
                else:
                    if momentum == True:
                        print(f"Using Linear with lr={lr} with momentum 0.9")
                    else:
                        print(f"Using Linear with lr={lr} without momentum")
                type_of_regression = str_to_class(reg)   
                model = type_of_regression(**params)  
                model.fit(X_train, y_train)
                yhat = model.predict(X_train)
                mse = model.avgMSE()
                r2 = model.avgr2()
                

                print("Test MSE: ", mse)
                print("Test R2: ", r2)

                mlflow.log_metric(key="test_mse", value=mse)
                mlflow.log_metric(key="test_r2", value=r2)

                signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
                mlflow.sklearn.log_model(model, artifact_path='model', signature=signature)

                mlflow.end_run()
# Out:
# ===== Ridge =====
# Using Polynomial with lr=0.01
# Using momentum:0.9
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Ridge =====
# Using Polynomial with lr=0.01
# Without using momentum
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Ridge =====
# Using Polynomial with lr=0.001
# Using momentum:0.9
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Ridge =====
# Using Polynomial with lr=0.001
# Without using momentum
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# ===== Ridge =====
# Using Polynomial with lr=0.0001
# Using momentum:0.9
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# ...

# %% [markdown]
# # SEE the best result for MSE above and write which regression with which regularization and which lr with or without momentum performed best

# %% [markdown]
# ## Grid Search.
#  - This include all regularization methods *Ridge, Lasso, Elasticnet, Normal
#  - Testing of polynomial or linear
#  - Testing in batches of mini, batch or stochastic batch
#  - Testing in learning rate of 0.01, 0.001 and 0.0001
#  - Using momentum or without momentum in the model

# %%
regs = ["Ridge", "Lasso", "ElasticNet","Normal"]
ispoly= [True, False]
lrs = [0.01,0.001,0.0001]
momentums =[True, False]
inits = ['zero','xavier']
methods = ["sto","mini","batch"]
for reg in regs:
    print("="*5, reg, "="*5)
    for method in methods:
        for init in inits:
            for t in ispoly:
                for lr in lrs:
                    for momentum in momentums:
                        params = {"method": method,"polynomial": t,  "lr": lr, "l": 0.1, "grad_init" :init, 
                        "degree":2, "use_momentum" :momentum,  "momentum":0.9}
                        mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{t}-momentum{momentum}-initialization{init}", nested=True)
                        
                        if t == True:
                            if momentum == True:
                                print(f"Using Polynomial with lr={lr} and initialization as {init} and method {method} using momentum = 0.9")
                            else:
                                print(f"Using Polynomial with lr={lr} and initialization as {init} and method {method} without using momentum")
                        else:                            
                            if momentum == True:
                                print(f"Using Linear with lr={lr} and initialization as {init} and method {method} using momentum = 0.9")
                            else:
                                print(f"Using Linear with lr={lr} and initialization as {init} and method {method} without using momentum")
                        print("*"*10)
                        type_of_regression = str_to_class(reg)   
                        model = type_of_regression(**params)  
                        model.fit(X_train, y_train)
                        yhat = model.predict(X_train)
                        mse = model.avgMSE()
                        r2 = model.avgr2()
                        

                        print("Test MSE: ", mse)
                        print("Test R2: ", r2)

                        mlflow.log_metric(key="test_mse", value=mse)
                        mlflow.log_metric(key="test_r2", value=r2)

                        signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
                        mlflow.sklearn.log_model(model, artifact_path='model', signature=signature)

                        mlflow.end_run()
# Out:
# ===== Ridge =====
# Using Polynomial with lr=0.01 and initialization as zero and method sto using momentum = 0.9
# **********
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# Using Polynomial with lr=0.01 and initialization as zero and method sto without using momentum
# **********
# Using Polynomial
# Fold 0: inf
# Fold 0: -inf
# Fold 1: inf
# Fold 1: -inf
# Fold 2: inf
# Fold 2: -inf
# Test MSE:  inf
# Test R2:  -inf
# Using Polynomial with lr=0.001 and initialization as zero and method sto using momentum = 0.9
# **********
# Using Polynomial
# Fold 0: 5388.047310377402
# Fold 0: -7846.649436165084
# Fold 1: 20.786376216635205
# Fold 1: -27.739287332253873
# Fold 2: 33.206472086428846
# Fold 2: -46.81886617299455
# Test MSE:  1814.0133862268221
# Test R2:  -2640.402529890111
# Using Polynomial with lr=0.001 and initialization as zero and method sto without using momentum
# **********
# ...

# %% [markdown]
# ## 6. Testing

# %% [markdown]
# # SEE the best result for MSE above and write which regression with which regularization and which lr with or without momentum performed best and use the parameter below in the testing code

# %% [markdown]
# We found the best model to be Normal with linear regression in mini batch without momentum, learning rate at 0.001, and Xavier initialization.

# %%
## RE-RUNNING THE BEST EXPERIMENT AGAIN HERE
regs = "Normal"
ispoly= False
method = "mini"
momentum = False
init = 'xavier'
lr = 0.001

params = {"method": method,"polynomial": ispoly,  "lr": lr, "l": 0.1, "grad_init" :init, 
"degree":2, "use_momentum" :momentum,  "momentum":0.9}
mlflow.start_run(run_name=f"method-{params['method']}-lr-{params['lr']}-reg-{reg}-poly-{ispoly}-momentum-{momentum}-init-{init}", nested=True)

print("="*5, reg, "="*5)
print("Method:", method)
print("Polynomial: ", ispoly)
print("Momentun: ", momentum)
print("Initialization: ", init)
print("Learning Rate: ", lr)
print("="*10)


type_of_regression = str_to_class(reg)    
model = type_of_regression(**params)  
model.fit(X_train, y_train)
yhat = model.predict(X_test)
mse  = model.mse(yhat, y_test)
r2 = model.r2(yhat, y_test)

print("Best MSE: ", mse)
print("Best R2: ", r2)

mlflow.log_metric(key="test_mse", value=mse)
mlflow.log_metric(key="test_r2", value=r2)

signature = mlflow.models.infer_signature(X_train, model.predict(X_train))
mlflow.sklearn.log_model(model, artifact_path='model', signature=signature)
mlflow.end_run()
# Out:
# ===== Normal =====
# Method: mini
# Polynomial:  False
# Momentun:  False
# Initialization:  xavier
# Learning Rate:  0.001
# ...
# Using Linear
# Fold 0 mse: 0.2730158247659695
# Fold 0 r2: 0.6023545526108729
# Fold 1 mse: 0.29223313264982026
# Fold 1 r2: 0.595957858180854
# Fold 2 mse: 0.27889099615726815
# Fold 2 r2: 0.5983839780574601
# Best MSE:  0.2769946060926892
# Best R2:  0.3627507796447208

# %% [markdown]
# ## 7. Analysis:  Feature Importance

# %%
print(model._coef())
print(X.columns)
# Out:
# [0.31407681 0.22802108 0.55764656]
# Index(['mileage', 'engine', 'max_power'], dtype='object')

# %%
columns = X.columns
def feature_importance(model, columns):
            if model._coef is not None and columns is not None:
                coefs = pd.DataFrame(data=model._coef(), index=columns, columns=["coef"])  
                coefs.plot(kind='barh', figsize=(10, 10))
                plt.title("Feature Importance")
                plt.axvline(x=0, color='.5')
                plt.subplots_adjust(left=.3)
                plt.show()
            else:
                print("No features found to calculate the feature importance")


feature_importance(model, columns)

# %% [markdown]
# From the plotting of feature importance across all columns even the one hot encoded one. We find out that the type of brand of car, its year of manufacture are some of the integral features of prediction in the model. However, we also find out that some brands have higher weights than the other in the Linear Regression (which can be taken as a major drawback of our custom model).

# %% [markdown]
# ## 8. Inference
#
# We are now going to compare the new model with the previous one (as the brands was label encoded the model was recreated with one hot enncoding in order to compare previously it was label encoded).
# We are going to compare through X_test and a sample value

# %%
import pickle

# save the model to disk
filename = 'car-a2-prediction2.pkl'
pickle.dump(model, open(filename, 'wb'))

# save the scaler to disk
scaler_path = 'a2r-scalar2.model'
pickle.dump(scaler, open(scaler_path, 'wb'))

# %%
# paths of all components for car price predictions
old_model_path = './app/car_price_prediction.model'  
new_model_path = './app/car-a2-prediction.pkl'
scaler_path = './app/a2r-scalar.model'

# load all components
old_model = pickle.load(open(old_model_path, 'rb'))
new_model = pickle.load(open(new_model_path, 'rb'))
scalar = pickle.load(open(scaler_path, 'rb'))

# %%
# predict selling prices in our test set using old and new models
old_y_pred = old_model.predict(X_test)
print(f"Predicted old model selling price: {np.exp(old_model.predict(X_test)[0])}")
new_y_pred = new_model.predict(X_test)
print(f"Predicted new model selling price: {np.exp(new_model.predict(X_test)[0])}")
print(f"(Actual price:{np.exp(y_test[0])}")
# Out:
# Predicted old model selling price: 711879.532212406
# Predicted new model selling price: 284978.63122003915
# (Actual price:450000.00000000035

# %%
def mse(ytrue, ypred):
    return ((ypred - ytrue) ** 2).sum() / ytrue.shape[0]

def r2(ytrue, ypred):
    return 1 - ((ytrue - ypred) ** 2).sum() / ((ytrue - ytrue.mean()) ** 2).sum()

# %%
print("Model in assignment-1")
print("MSE: ", mse(y_test, old_y_pred))
print("r2: ", r2(y_test, yhat))

print("Model in assignment-1")
print("MSE: ", mse(y_test, new_y_pred))
print("r2: ", r2(y_test, yhat))
# Out:
# Model in assignment-1
# MSE:  0.600661773806464
# r2:  0.6063107050501233
# Model in assignment-1
# MSE:  0.2770156464925229
# r2:  0.6063107050501233

# %%
X_test
# Out:
# array([[ 1.        , -1.11398395, -0.18006574, -0.05063609],
#        [ 1.        ,  0.06447149,  0.24837778,  0.97141605],
#        [ 1.        ,  0.27644206, -0.92083257, -0.6988769 ],
#        ...,
#        [ 1.        , -0.73546507, -0.57247195, -0.75647321],
#        [ 1.        ,  1.23283308, -0.42031444, -0.09298632],
#        [ 1.        ,  0.42532615, -1.28921391, -1.03316136]])

# %%
y_test
# Out:
# 5948    12.323856
# 6039    13.710150
# 3069    12.676076
# 6531    13.384728
# 322     13.161584
#           ...
# 5744    12.206073
# 1010    13.304685
# 4856    11.918391
# 7542    13.384728
# 560     12.611538
# Name: selling_price, Length: 2409, dtype: float64

# %%
with open('model.pkl', 'wb') as model_file:
    pickle.dump(model, model_file)
